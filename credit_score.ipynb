# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter


#imported necessary Library

# %%
df=pd.read_csv(r'C:\\Users\\HP\Downloads\Credit-Score-Data\train.csv')

df.info() #checking the data info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
#  13  Type_of_Loan              100000 non-null  object
#  14  Delay_from_due_date       100000 non-null  float64
#  15  Num_of_Delayed_Payment    100000 non-null  float64
#  16  Changed_Credit_Limit      100000 non-null  float64
#  17  Num_Credit_Inquiries      100000 non-null  float64
#  18  Credit_Mix                100000 non-null  object
#  19  Outstanding_Debt          100000 non-null  float64
#  20  Credit_Utilization_Ratio  100000 non-null  float64
#  21  Credit_History_Age        100000 non-null  float64
#  22  Payment_of_Min_Amount     100000 non-null  object
#  23  Total_EMI_per_month       100000 non-null  float64
#  24  Amount_invested_monthly   100000 non-null  float64
#  25  Payment_Behaviour         100000 non-null  object
#  26  Monthly_Balance           100000 non-null  float64
#  27  Credit_Score              100000 non-null  object
# dtypes: float64(18), int64(3), object(7)
# memory usage: 21.4+ MB

# %% [markdown]
# data input stay correct ✔

# %%
#checkin the data

df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 0            809.98                 26.822620              265.0
# 1            809.98                 31.944960              266.0
# 2            809.98                 28.609352              267.0
# 3            809.98                 31.377862              268.0
# 4            809.98                 24.797347              269.0
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                     No            49.574949                 21.46538
# 1                     No            49.574949                 21.46538
# 2                     No            49.574949                 21.46538
# 3                     No            49.574949                 21.46538
# 4                     No            49.574949                 21.46538
#
#                   Payment_Behaviour Monthly_Balance  Credit_Score
# 0   High_spent_Small_value_payments      312.494089          Good
# 1    Low_spent_Large_value_payments      284.629162          Good
# 2   Low_spent_Medium_value_payments      331.209863          Good
# 3    Low_spent_Small_value_payments      223.451310          Good
# 4  High_spent_Medium_value_payments      341.489231          Good
#
# [5 rows x 28 columns]

# %%
#getting the shape of the Data


print('This dataset is  make up of :',df.shape[0],'rows & Columns is made up',df.shape[1])
# Out:
# This dataset is  make up of : 100000 rows & Columns is made up 28

# %%
#let get the full columns 

pd.set_option('display.max_columns',28)

# %%
#Let view

df.head(3)
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
# 1            3.0          4.0
# 2            3.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                     7.0                 11.27                   4.0
# 1                     4.0                 11.27                   4.0
# 2                     7.0                 11.27                   4.0
#
#   Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0       Good            809.98                 26.822620               265.0
# 1       Good            809.98                 31.944960               266.0
# 2       Good            809.98                 28.609352               267.0
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949                 21.46538
# 1                    No            49.574949                 21.46538
# 2                    No            49.574949                 21.46538
#
#                  Payment_Behaviour  Monthly_Balance Credit_Score
# 0  High_spent_Small_value_payments       312.494089         Good
# 1   Low_spent_Large_value_payments       284.629162         Good
# 2  Low_spent_Medium_value_payments       331.209863         Good

# %%
#creating a Numeric columns 

num_df=df.select_dtypes('number')

# %%
#also creating a Object columns


cat_df=df.select_dtypes('object')

cat_df
# Out:
#                 Name Occupation  \
# 0      Aaron Maashoh  Scientist
# 1      Aaron Maashoh  Scientist
# 2      Aaron Maashoh  Scientist
# 3      Aaron Maashoh  Scientist
# 4      Aaron Maashoh  Scientist
# ...              ...        ...
# 99995          Nicks   Mechanic
# 99996          Nicks   Mechanic
# 99997          Nicks   Mechanic
# 99998          Nicks   Mechanic
# 99999          Nicks   Mechanic
#
#                                             Type_of_Loan Credit_Mix  \
# 0      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 2      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 3      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...       Good
# ...                                                  ...        ...
# 99995                        Auto Loan, and Student Loan       Good
# 99996                        Auto Loan, and Student Loan       Good
# 99997                        Auto Loan, and Student Loan       Good
# 99998                        Auto Loan, and Student Loan       Good
# 99999                        Auto Loan, and Student Loan       Good
#
#       Payment_of_Min_Amount                 Payment_Behaviour Credit_Score
# 0                        No   High_spent_Small_value_payments         Good
# 1                        No    Low_spent_Large_value_payments         Good
# 2                        No   Low_spent_Medium_value_payments         Good
# 3                        No    Low_spent_Small_value_payments         Good
# 4                        No  High_spent_Medium_value_payments         Good
# ...                     ...                               ...          ...
# 99995                    No   High_spent_Large_value_payments         Poor
# 99996                    No  High_spent_Medium_value_payments         Poor
# 99997                    No   High_spent_Large_value_payments         Poor
# 99998                    No    Low_spent_Large_value_payments     Standard
# 99999                    No  High_spent_Medium_value_payments         Poor
#
# [100000 rows x 7 columns]

# %%
#with this division of dataframe sketch can us with columns description

import sketch

cat_df.sketch.ask('can you give me a friendly names and single sentence descriptions of each column ?(format output as HTML List)')
# Out:
# <ul>
#   <li><strong>Index:</strong> Unique numerical identifier for each row in the dataframe.</li>
#   <li><strong>Name:</strong> Name of the person associated with the data.</li>
#   <li><strong>Occupation:</strong> Occupation of the person associated with the data.</li>
#   <li><strong>Type_of_Loan:</strong> Type of loan associated with the data.</li>
#   <li><strong>Credit_Mix:</strong> Credit mix associated with the data.</li>
#   <li><strong>Payment_of_Min_Amount:</strong> Payment of minimum amount associated with the data.</li>
#   <li><strong>Payment_Behaviour:</strong> Payment behaviour associated with the data.</li>
#   <li><strong>Credit_Score:</strong> Credit score associated with the data.</li>
# </ul>

# %%
#All Thanks to Sketch!!!
#creating a function for value uniqueness

def uniqness(df):
    for i in df.columns:
        print(f'{i}:{df[i].unique()}')

# %%
uniqness(cat_df)
# Out:
# Name:['Aaron Maashoh' 'Rick Rothackerj' 'Langep' ... 'Chris Wickhamm'
#  'Sarah McBridec' 'Nicks']
# Occupation:['Scientist' 'Teacher' 'Engineer' 'Entrepreneur' 'Developer' 'Lawyer'
#  'Media_Manager' 'Doctor' 'Journalist' 'Manager' 'Accountant' 'Musician'
#  'Mechanic' 'Writer' 'Architect']
# Type_of_Loan:['Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan'
#  'Credit-Builder Loan' 'Auto Loan, Auto Loan, and Not Specified' ...
#  'Home Equity Loan, Auto Loan, Auto Loan, and Auto Loan'
#  'Payday Loan, Student Loan, Mortgage Loan, and Not Specified'
#  'Personal Loan, Auto Loan, Mortgage Loan, Student Loan, and Student Loan']
# Credit_Mix:['Good' 'Standard' 'Bad']
# Payment_of_Min_Amount:['No' 'NM' 'Yes']
# Payment_Behaviour:['High_spent_Small_value_payments' 'Low_spent_Large_value_payments'
#  'Low_spent_Medium_value_payments' 'Low_spent_Small_value_payments'
#  'High_spent_Medium_value_payments' 'High_spent_Large_value_payments']
# Credit_Score:['Good' 'Standard' 'Poor']

# %% [markdown]
# EDA:

# %%
#getting the value count of the Loan type

cat_df['Type_of_Loan'].value_counts()
# Out:
# No Data                                                                                                                               11408
# Not Specified                                                                                                                          1408
# Credit-Builder Loan                                                                                                                    1280
# Personal Loan                                                                                                                          1272
# Debt Consolidation Loan                                                                                                                1264
#                                                                                                                                       ...
# Not Specified, Mortgage Loan, Auto Loan, and Payday Loan                                                                                  8
# Payday Loan, Mortgage Loan, Debt Consolidation Loan, and Student Loan                                                                     8
# Debt Consolidation Loan, Auto Loan, Personal Loan, Debt Consolidation Loan, Student Loan, and Credit-Builder Loan                         8
# Student Loan, Auto Loan, Student Loan, Credit-Builder Loan, Home Equity Loan, Debt Consolidation Loan, and Debt Consolidation Loan        8
# Personal Loan, Auto Loan, Mortgage Loan, Student Loan, and Student Loan                                                                   8
# Name: Type_of_Loan, Length: 6261, dtype: int64

# %%
#putting this to frame

df['Type_of_Loan'].value_counts().to_frame()
# Out:
#                                                     Type_of_Loan
# No Data                                                    11408
# Not Specified                                               1408
# Credit-Builder Loan                                         1280
# Personal Loan                                               1272
# Debt Consolidation Loan                                     1264
# ...                                                          ...
# Not Specified, Mortgage Loan, Auto Loan, and Pa...             8
# Payday Loan, Mortgage Loan, Debt Consolidation ...             8
# Debt Consolidation Loan, Auto Loan, Personal Lo...             8
# Student Loan, Auto Loan, Student Loan, Credit-B...             8
# Personal Loan, Auto Loan, Mortgage Loan, Studen...             8
#
# [6261 rows x 1 columns]

# %%
#trying to figure out why Number of Loan and The Loan tye, 
#They Seems to be thesame the only different is one is Nuemric why one is object catgeory

df[:1]
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                     7.0                 11.27                   4.0
#
#   Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0       Good            809.98                  26.82262               265.0
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949                 21.46538
#
#                  Payment_Behaviour  Monthly_Balance Credit_Score
# 0  High_spent_Small_value_payments       312.494089         Good

# %%
#figuring out the type of loan individual have collected, because i noticed custumer have colleted more than one loan 

loan=df[:2]

df['Type_of_Loan'][1]
# Out:
# 'Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan'

# %%
#let check for duplicated values, we never can tell

df.duplicated().sum()
# Out:
# 0

# %%
#let Used credit mix columns 


good_df=df.query('Credit_Mix=="Good"')

# %%
good_df[:5]
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
# 1            3.0          4.0
# 2            3.0          4.0
# 3            3.0          4.0
# 4            3.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 3  Auto Loan, Credit-Builder Loan, Personal Loan,...                  5.0
# 4  Auto Loan, Credit-Builder Loan, Personal Loan,...                  6.0
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                     7.0                 11.27                   4.0
# 1                     4.0                 11.27                   4.0
# 2                     7.0                 11.27                   4.0
# 3                     4.0                  6.27                   4.0
# 4                     4.0                 11.27                   4.0
#
#   Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0       Good            809.98                 26.822620               265.0
# 1       Good            809.98                 31.944960               266.0
# 2       Good            809.98                 28.609352               267.0
# 3       Good            809.98                 31.377862               268.0
# 4       Good            809.98                 24.797347               269.0
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949                 21.46538
# 1                    No            49.574949                 21.46538
# 2                    No            49.574949                 21.46538
# 3                    No            49.574949                 21.46538
# 4                    No            49.574949                 21.46538
#
#                   Payment_Behaviour  Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments       312.494089         Good
# 1    Low_spent_Large_value_payments       284.629162         Good
# 2   Low_spent_Medium_value_payments       331.209863         Good
# 3    Low_spent_Small_value_payments       223.451310         Good
# 4  High_spent_Medium_value_payments       341.489231         Good

# %% [markdown]
# WHat Are attribute that make custumer a good Credit mix and a bad credit Mix? let check ?

# %%
#Yes, I remeber One Of this statistical Method,getting to the differences between lowest and The max Amount` 

np.ptp(good_df['Annual_Income'])
# Out:
# 170487.04499999998

# %%
#let look at bad credit mix, what make it different ?

bad_df=df.query('Credit_Mix=="Bad"')


bad_df
# Out:
#            ID  Customer_ID  Month            Name   Age         SSN  \
# 152      5862        16640      1           Reema  31.0  68834394.0
# 153      5863        16640      2           Reema  31.0  68834394.0
# 154      5864        16640      3           Reema  31.0  68834394.0
# 155      5865        16640      4           Reema  31.0  68834394.0
# 156      5866        16640      5           Reema  32.0  68834394.0
# ...       ...          ...    ...             ...   ...         ...
# 99987  155613        34304      4  Sarah McBridec  28.0  31350942.0
# 99988  155614        34304      5  Sarah McBridec  28.0  31350942.0
# 99989  155615        34304      6  Sarah McBridec  28.0  31350942.0
# 99990  155616        34304      7  Sarah McBridec  28.0  31350942.0
# 99991  155617        34304      8  Sarah McBridec  29.0  31350942.0
#
#          Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 152    Entrepreneur       19300.34            1512.361667                6.0
# 153    Entrepreneur       19300.34            1512.361667                6.0
# 154    Entrepreneur       19300.34            1512.361667                6.0
# 155    Entrepreneur       19300.34            1512.361667                6.0
# 156    Entrepreneur       19300.34            1512.361667                6.0
# ...             ...            ...                    ...                ...
# 99987     Architect       20002.88            1929.906667               10.0
# 99988     Architect       20002.88            1929.906667               10.0
# 99989     Architect       20002.88            1929.906667               10.0
# 99990     Architect       20002.88            1929.906667               10.0
# 99991     Architect       20002.88            1929.906667               10.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 152                7.0           17.0          5.0
# 153                7.0           17.0          5.0
# 154                7.0           17.0          5.0
# 155                7.0           17.0          5.0
# 156                7.0           17.0          5.0
# ...                ...            ...          ...
# 99987              8.0           29.0          5.0
# 99988              8.0           29.0          5.0
# 99989              8.0           29.0          5.0
# 99990              8.0           29.0          5.0
# 99991              8.0           29.0          5.0
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 152    Mortgage Loan, Debt Consolidation Loan, Payday...                 52.0
# 153    Mortgage Loan, Debt Consolidation Loan, Payday...                 51.0
# 154    Mortgage Loan, Debt Consolidation Loan, Payday...                 48.0
# 155    Mortgage Loan, Debt Consolidation Loan, Payday...                 51.0
# 156    Mortgage Loan, Debt Consolidation Loan, Payday...                 51.0
# ...                                                  ...                  ...
# 99987  Personal Loan, Auto Loan, Mortgage Loan, Stude...                 33.0
# 99988  Personal Loan, Auto Loan, Mortgage Loan, Stude...                 33.0
# 99989  Personal Loan, Auto Loan, Mortgage Loan, Stude...                 33.0
# 99990  Personal Loan, Auto Loan, Mortgage Loan, Stude...                 33.0
# 99991  Personal Loan, Auto Loan, Mortgage Loan, Stude...                 33.0
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 152                      19.0                  9.95                   7.0
# 153                      18.0                  9.95                   7.0
# 154                      19.0                 15.95                   7.0
# 155                      19.0                  9.95                   7.0
# 156                      19.0                  9.95                   7.0
# ...                       ...                   ...                   ...
# 99987                    25.0                 18.31                   9.0
# 99988                    25.0                 18.31                   9.0
# 99989                    25.0                 16.31                   9.0
# 99990                    25.0                 18.31                   9.0
# 99991                    25.0                 18.31                   9.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 152          Bad           2430.21                 29.934186
# 153          Bad           2430.21                 36.641204
# 154          Bad           2430.21                 37.624862
# 155          Bad           2430.21                 28.870387
# 156          Bad           2430.21                 28.058846
# ...          ...               ...                       ...
# 99987        Bad           3571.70                 30.614953
# 99988        Bad           3571.70                 28.508250
# 99989        Bad           3571.70                 33.359987
# 99990        Bad           3571.70                 25.123535
# 99991        Bad           3571.70                 37.140784
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 152                 218.0                   Yes            49.572062
# 153                 219.0                    NM            49.572062
# 154                 220.0                   Yes            49.572062
# 155                 221.0                   Yes            49.572062
# 156                 222.0                   Yes            49.572062
# ...                   ...                   ...                  ...
# 99987                71.0                   Yes            60.964772
# 99988                72.0                   Yes            60.964772
# 99989                73.0                   Yes            60.964772
# 99990                74.0                   Yes            60.964772
# 99991                75.0                   Yes            60.964772
#
#        Amount_invested_monthly                Payment_Behaviour  \
# 152                  44.509510   Low_spent_Small_value_payments
# 153                  44.509510  High_spent_Small_value_payments
# 154                  44.509510   Low_spent_Large_value_payments
# 155                  44.509510  High_spent_Small_value_payments
# 156                  44.509510   Low_spent_Small_value_payments
# ...                        ...                              ...
# 99987                34.662906  High_spent_Large_value_payments
# 99988                34.662906   Low_spent_Small_value_payments
# 99989                34.662906   Low_spent_Small_value_payments
# 99990                34.662906   Low_spent_Large_value_payments
# 99991                34.662906  High_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score
# 152         312.487689         Poor
# 153         306.365891         Poor
# 154         230.845509         Poor
# 155         300.236075     Standard
# 156         218.621554         Poor
# ...                ...          ...
# 99987       328.301277     Standard
# 99988       208.047884     Standard
# 99989       307.659291     Standard
# 99990       228.750392     Standard
# 99991       337.362988     Standard
#
# [23768 rows x 28 columns]

# %%
#getting the Max values and minmum value

def minmax(X):
    max_ind=df[X].idxmax()
    min_ind=df[X].idxmin()
    maximum=pd.DataFrame(df.loc[max_ind,:])
    minimum=pd.DataFrame(df.loc[min_ind,:])
    return pd.concat([maximum,minimum],axis=1)

minmax('Annual_Income')
# Out:
#                                                                       15688  \
# ID                                                                    29166
# Customer_ID                                                            5960
# Month                                                                     1
# Name                                                        Olga Dzyubenkop
# Age                                                                    34.0
# SSN                                                             958256723.0
# Occupation                                                         Mechanic
# Annual_Income                                                     179987.28
# Monthly_Inhand_Salary                                              14816.94
# Num_Bank_Accounts                                                       5.0
# Num_Credit_Card                                                         5.0
# Interest_Rate                                                           8.0
# Num_of_Loan                                                             4.0
# Type_of_Loan              Mortgage Loan, Auto Loan, Personal Loan, and C...
# Delay_from_due_date                                                    14.0
# Num_of_Delayed_Payment                                                 11.0
# Changed_Credit_Limit                                                   0.54
# Num_Credit_Inquiries                                                    1.0
# Credit_Mix                                                             Good
# Outstanding_Debt                                                     741.28
# Credit_Utilization_Ratio                                           25.43759
# Credit_History_Age                                                    247.0
# Payment_of_Min_Amount                                                    No
# Total_EMI_per_month                                              417.843991
# Amount_invested_monthly                                          107.772897
# Payment_Behaviour                            Low_spent_Small_value_payments
# Monthly_Balance                                                   97.422321
# Credit_Score                                                           Poor
#
#                                                                       39672
# ID                                                                    65142
# Customer_ID                                                            6205
# Month                                                                     1
# Name                                                                 Whiteb
# Age                                                                    14.0
# SSN                                                             259110934.0
# Occupation                                                           Writer
# Annual_Income                                                       7005.93
# Monthly_Inhand_Salary                                              835.8275
# Num_Bank_Accounts                                                      10.0
# Num_Credit_Card                                                         7.0
# Interest_Rate                                                          30.0
# Num_of_Loan                                                             6.0
# Type_of_Loan              Student Loan, Payday Loan, Home Equity Loan, P...
# Delay_from_due_date                                                    21.0
# Num_of_Delayed_Payment                                                 11.0
# Changed_Credit_Limit                                                   5.49
# Num_Credit_Inquiries                                                    9.0
# Credit_Mix                                                         Standard
# Outstanding_Debt                                                    1703.39
# Credit_Utilization_Ratio                                          29.341779
# Credit_History_Age                                                    131.0
# Payment_of_Min_Amount                                                   Yes
# Total_EMI_per_month                                               18.672909
# Amount_invested_monthly                                            15.30177
# Payment_Behaviour                            Low_spent_Small_value_payments
# Monthly_Balance                                                  243.962927
# Credit_Score                                                           Poor

# %% [markdown]
# A credit score is a numerical representation of an individual's creditworthiness. That is ,
# It is a measure of how likely a person is to repay their debts and fulfill financial obligations based on their past borrowing and repayment behavior.
#
# We Have two different custumer over Here, One is Mechanic while one is Writer. Mechanic happen to be earning *10 of what Writer is earning but till yet is till have a poor credi score but on the bright Side is a good custumer because is earning is Big.
#
# what Make the Mechanic be a baad ccustumer ? I don't known, may repayment behaviour? they both have 11 days repayment behaiour.
#
# --> The teacher outstanding Debit Seems to be Higher than the Mechanic Waoh!!! but did this contribute to the Credit Scores?
#  i don't know ?
#
#
# But on the Bright side we will be making more moneey by given the mechanic loan than the Teacher, nevertheless all are custumer because The More we lend out the more income we get as a Company and we aim at making more profit.

# %% [markdown]
# **Data Observation:**
#
# One of the beautiful trend of the data is the custumer occupation, they didn't look at your Annual Income to categorize their creditworthiness rather they look at your repayment behaviour and their outstanding Debit to generalizze their  creditworthiness.

# %%
#getting the Max values and The mean values for bad credir record for credit_history_age

def minmax(X):
    max_ind=good_df[X].idxmax()
    min_ind=good_df[X].idxmin()
    maximum=pd.DataFrame(good_df.loc[max_ind,:])
    minimum=pd.DataFrame(good_df.loc[min_ind,:])
    return pd.concat([maximum,minimum],axis=1)

minmax('Num_of_Delayed_Payment')
# Out:
#                                                      7736  \
# ID                                                  17238
# Customer_ID                                         29583
# Month                                                   1
# Name                                      Katharina Barty
# Age                                                  40.0
# SSN                                           995652513.0
# Occupation                                       Mechanic
# Annual_Income                                     9767.32
# Monthly_Inhand_Salary                          872.943333
# Num_Bank_Accounts                                     5.0
# Num_Credit_Card                                       7.0
# Interest_Rate                                         3.0
# Num_of_Loan                                           1.0
# Type_of_Loan                                Not Specified
# Delay_from_due_date                                  18.0
# Num_of_Delayed_Payment                               23.0
# Changed_Credit_Limit                                 2.47
# Num_Credit_Inquiries                                  3.0
# Credit_Mix                                           Good
# Outstanding_Debt                                   327.25
# Credit_Utilization_Ratio                        25.882286
# Credit_History_Age                                  184.0
# Payment_of_Min_Amount                                  No
# Total_EMI_per_month                              7.867826
# Amount_invested_monthly                         19.676958
# Payment_Behaviour         High_spent_Large_value_payments
# Monthly_Balance                                 299.74955
# Credit_Score                                         Good
#
#                                                      13
# ID                                                   5651
# Customer_ID                                          8625
# Month                                                   6
# Name                                      Rick Rothackerj
# Age                                                  28.0
# SSN                                             4075839.0
# Occupation                                        Teacher
# Annual_Income                                    34847.84
# Monthly_Inhand_Salary                         3037.986667
# Num_Bank_Accounts                                     2.0
# Num_Credit_Card                                       4.0
# Interest_Rate                                         6.0
# Num_of_Loan                                           1.0
# Type_of_Loan                          Credit-Builder Loan
# Delay_from_due_date                                   3.0
# Num_of_Delayed_Payment                                0.0
# Changed_Credit_Limit                                 5.42
# Num_Credit_Inquiries                                  2.0
# Credit_Mix                                           Good
# Outstanding_Debt                                   605.03
# Credit_Utilization_Ratio                         33.38101
# Credit_History_Age                                  324.0
# Payment_of_Min_Amount                                  No
# Total_EMI_per_month                             18.816215
# Amount_invested_monthly                         39.684018
# Payment_Behaviour         High_spent_Large_value_payments
# Monthly_Balance                                481.505262
# Credit_Score                                         Good

# %% [markdown]
# According to DataSet; They claim that credit Mix is good when Num_of day of repayment  hit 23 days and Credit_score till record Good when it Exceed 23 days **Waoh**,of repayment and 23 days is maximum !!!😮😮
#
# Are They any other thing they are putting into condisderation we don't know ???
#
# LEt check ?

# %% [markdown]
# I think they also putting outstanding debit into consideration of custumers behaviour, because how can you exceed 23 days of num of repayment and till recorded as Good Credit scores?
#
#
# let check for the bad Custumer

# %%
#getting the Max values and The mean values for bad credir record for credit_history_age

def minmax(X):
    max_ind=bad_df[X].idxmax()
    min_ind=bad_df[X].idxmin()
    maximum=pd.DataFrame(bad_df.loc[max_ind,:])
    minimum=pd.DataFrame(bad_df.loc[min_ind,:])
    return pd.concat([maximum,minimum],axis=1)

minmax('Num_of_Delayed_Payment')
# Out:
#                                                                        541   \
# ID                                                                     6443
# Customer_ID                                                           41302
# Month                                                                     6
# Name                                                         Silvia Aloisiq
# Age                                                                    42.0
# SSN                                                             405467599.0
# Occupation                                                     Entrepreneur
# Annual_Income                                                      58674.66
# Monthly_Inhand_Salary                                              4824.555
# Num_Bank_Accounts                                                       8.0
# Num_Credit_Card                                                         5.0
# Interest_Rate                                                          15.0
# Num_of_Loan                                                             4.0
# Type_of_Loan              Not Specified, Payday Loan, Auto Loan, and Hom...
# Delay_from_due_date                                                    57.0
# Num_of_Delayed_Payment                                                 25.0
# Changed_Credit_Limit                                                   1.29
# Num_Credit_Inquiries                                                   11.0
# Credit_Mix                                                              Bad
# Outstanding_Debt                                                    2425.38
# Credit_Utilization_Ratio                                          34.990813
# Credit_History_Age                                                    162.0
# Payment_of_Min_Amount                                                   Yes
# Total_EMI_per_month                                              116.103417
# Amount_invested_monthly                                           69.228233
# Payment_Behaviour                            Low_spent_Small_value_payments
# Monthly_Balance                                                   27.642931
# Credit_Score                                                       Standard
#
#                                                                        2873
# ID                                                                     9943
# Customer_ID                                                           24621
# Month                                                                     2
# Name                                                           Gavin Jonesu
# Age                                                                    15.0
# SSN                                                              41286430.0
# Occupation                                                          Teacher
# Annual_Income                                                      20639.79
# Monthly_Inhand_Salary                                             1541.9825
# Num_Bank_Accounts                                                       7.0
# Num_Credit_Card                                                         5.0
# Interest_Rate                                                          15.0
# Num_of_Loan                                                             9.0
# Type_of_Loan              Payday Loan, Auto Loan, Mortgage Loan, Auto Lo...
# Delay_from_due_date                                                    48.0
# Num_of_Delayed_Payment                                                 12.0
# Changed_Credit_Limit                                                  16.15
# Num_Credit_Inquiries                                                    8.0
# Credit_Mix                                                              Bad
# Outstanding_Debt                                                    4145.87
# Credit_Utilization_Ratio                                          27.870956
# Credit_History_Age                                                     11.0
# Payment_of_Min_Amount                                                   Yes
# Total_EMI_per_month                                                95.62691
# Amount_invested_monthly                                           42.748365
# Payment_Behaviour                           Low_spent_Medium_value_payments
# Monthly_Balance                                                  214.830652
# Credit_Score                                                       Standard

# %%
poor_df=df.query('Credit_Score=="Poor"')

# %%
#getting the Max values and The mean values for bad credir record for credit_history_age

def minmax(X):
    max_ind=poor_df[X].idxmax()
    min_ind=poor_df[X].idxmin()
    maximum=pd.DataFrame(poor_df.loc[max_ind,:])
    minimum=pd.DataFrame(poor_df.loc[min_ind,:])
    return pd.concat([maximum,minimum],axis=1)

minmax('Num_of_Delayed_Payment')
# Out:
#                                                                        1760  \
# ID                                                                     8274
# Customer_ID                                                           30439
# Month                                                                     1
# Name                                                                    env
# Age                                                                    26.0
# SSN                                                             532393348.0
# Occupation                                                          Manager
# Annual_Income                                                      34128.92
# Monthly_Inhand_Salary                                           2740.076667
# Num_Bank_Accounts                                                       6.0
# Num_Credit_Card                                                         8.0
# Interest_Rate                                                          31.0
# Num_of_Loan                                                             6.0
# Type_of_Loan              Student Loan, Personal Loan, Home Equity Loan,...
# Delay_from_due_date                                                    18.0
# Num_of_Delayed_Payment                                                 25.0
# Changed_Credit_Limit                                                   3.99
# Num_Credit_Inquiries                                                    9.0
# Credit_Mix                                                              Bad
# Outstanding_Debt                                                    2626.28
# Credit_Utilization_Ratio                                          36.329024
# Credit_History_Age                                                     65.0
# Payment_of_Min_Amount                                                   Yes
# Total_EMI_per_month                                              118.066855
# Amount_invested_monthly                                           21.338167
# Payment_Behaviour                            Low_spent_Small_value_payments
# Monthly_Balance                                                  172.828995
# Credit_Score                                                           Poor
#
#                                                       899
# ID                                                    6981
# Customer_ID                                          13914
# Month                                                    4
# Name                                             Aless ray
# Age                                                   54.0
# SSN                                             26575729.0
# Occupation                                       Scientist
# Annual_Income                                     41345.58
# Monthly_Inhand_Salary                             3260.465
# Num_Bank_Accounts                                      0.0
# Num_Credit_Card                                        5.0
# Interest_Rate                                         10.0
# Num_of_Loan                                            0.0
# Type_of_Loan                                       No Data
# Delay_from_due_date                                   12.0
# Num_of_Delayed_Payment                                 0.0
# Changed_Credit_Limit                                  6.42
# Num_Credit_Inquiries                                   7.0
# Credit_Mix                                            Good
# Outstanding_Debt                                    646.47
# Credit_Utilization_Ratio                         30.252518
# Credit_History_Age                                   340.0
# Payment_of_Min_Amount                                   No
# Total_EMI_per_month                                    0.0
# Amount_invested_monthly                          36.947205
# Payment_Behaviour         High_spent_Medium_value_payments
# Monthly_Balance                                 323.191854
# Credit_Score                                          Poor

# %% [markdown]
# The Company are not putting any mertrics or variable into consideration before segementing the custumer proper creditworthiness.
#
#
# So that  is the problem, and that what we doing

# %%
df['Occupation'].value_counts().plot.bar(figsize=(10,5),title='Custumer Occupation')
plt.xticks(rotation=15,ha='right');

# %%
data=df[['Name','Annual_Income','Occupation','Customer_ID']].groupby('Customer_ID').first()


data
# Out:
#                           Name  Annual_Income     Occupation
# Customer_ID
# 1006         Matthias Blamontb       16756.18     Journalist
# 1007              Soyoung Kimu       21212.91        Manager
# 1008                      Koht       33540.43      Developer
# 1009                       Edd       80983.64     Accountant
# 1011               Terry Wadeu      104142.56         Writer
# ...                        ...            ...            ...
# 50984                Victoriah       19267.17       Mechanic
# 50990                     Yueo       32125.54         Lawyer
# 50992             Jason Langev        9608.03     Journalist
# 50996                 Koh Guia       27305.93  Media_Manager
# 50999           Simon Johnsong       78676.32         Doctor
#
# [12500 rows x 3 columns]

# %%
df[['Occupation','Annual_Income']].groupby('Occupation').first().plot(kind='bar',title='Occupation Annual_Income',figsize=(15,4))
plt.xticks(rotation=35,ha='right');

# %%
df[['Occupation','Num_of_Loan']].groupby('Occupation').first().plot(kind='bar',title='Occupation Num_of_Loan',figsize=(15,4))
plt.xticks(rotation=35,ha='right');

# %%
df[['Occupation','Outstanding_Debt']].groupby('Occupation').first().plot(kind='bar',title='Occupation OutstandingDebt',figsize=(15,4))
plt.xticks(rotation=35,ha='right');

# %%
plt.figure(figsize=(16,5),dpi=100)
sns.barplot(data=df,x='Occupation',y='Outstanding_Debt',ci=None)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Outstanding_Debt'>

# %%
df['Credit_Score'].value_counts()
# Out:
# Standard    53174
# Poor        28998
# Good        17828
# Name: Credit_Score, dtype: int64

# %%
df['Credit_Mix'].value_counts()
# Out:
# Standard    45848
# Good        30384
# Bad         23768
# Name: Credit_Mix, dtype: int64

# %%
plt.figure(figsize=(16,5),dpi=100)
sns.barplot(data=df,x='Occupation',y='Num_Bank_Accounts',ci=None)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Num_Bank_Accounts'>

# %%
#Regular Custumers?

df['Name'].value_counts().to_frame()[:10]
# Out:
#                     Name
# Jessicad              48
# Langep                48
# Stevex                48
# Vaughanl              40
# Ronald Groverk        40
# Huwk                  40
# Andreaj               40
# Valetkevitchv         40
# Deepa Seetharamanm    40
# Danielz               40

# %%
#bottom level custumer?

df['Name'].value_counts().to_frame().tail(10)
# Out:
#                     Name
# Jeb Blountq            8
# iniz                   8
# Nicholasq              8
# Prodhane               8
# Harro Teni             8
# Breidthardtj           8
# Sven Egenterx          8
# Antonella Ciancioc     8
# Valentina Zan          8
# Nicks                  8

# %% [markdown]
# 💡
#
#
# is goinG to be a good idea if we can create a columns of Number of appearance, this is columns is going to Play major
#
# in Creditworthiness because with your Numbers Appearce we can trust you with our money, while with Limit appearance we can't really trust you with our loan but to play risky game with you.

# %%
df['Customer_ID'].value_counts()
# Out:
# 3392     8
# 30150    8
# 23368    8
# 49323    8
# 11708    8
#         ..
# 45340    8
# 44367    8
# 20915    8
# 8324     8
# 37932    8
# Name: Customer_ID, Length: 12500, dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Jessicad              48
# Langep                48
# Stevex                48
# Vaughanl              40
# Ronald Groverk        40
#                       ..
# Breidthardtj           8
# Sven Egenterx          8
# Antonella Ciancioc     8
# Valentina Zan          8
# Nicks                  8
# Name: Name, Length: 10128, dtype: int64

# %% [markdown]
# Am trying to figure out heree The option to used , either With custumer_id or Names?

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
# 1            3.0          4.0
# 2            3.0          4.0
# 3            3.0          4.0
# 4            3.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 3  Auto Loan, Credit-Builder Loan, Personal Loan,...                  5.0
# 4  Auto Loan, Credit-Builder Loan, Personal Loan,...                  6.0
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                     7.0                 11.27                   4.0
# 1                     4.0                 11.27                   4.0
# 2                     7.0                 11.27                   4.0
# 3                     4.0                  6.27                   4.0
# 4                     4.0                 11.27                   4.0
#
#   Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0       Good            809.98                 26.822620               265.0
# 1       Good            809.98                 31.944960               266.0
# 2       Good            809.98                 28.609352               267.0
# 3       Good            809.98                 31.377862               268.0
# 4       Good            809.98                 24.797347               269.0
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949                 21.46538
# 1                    No            49.574949                 21.46538
# 2                    No            49.574949                 21.46538
# 3                    No            49.574949                 21.46538
# 4                    No            49.574949                 21.46538
#
#                   Payment_Behaviour  Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments       312.494089         Good
# 1    Low_spent_Large_value_payments       284.629162         Good
# 2   Low_spent_Medium_value_payments       331.209863         Good
# 3    Low_spent_Small_value_payments       223.451310         Good
# 4  High_spent_Medium_value_payments       341.489231         Good

# %%
#let try This columns Name SSN

df['SSN'].value_counts()
# Out:
# 821000265.0    8
# 544050223.0    8
# 381365261.0    8
# 994731178.0    8
# 647449598.0    8
#               ..
# 936122774.0    8
# 91611869.0     8
# 576385212.0    8
# 281301712.0    8
# 78735990.0     8
# Name: SSN, Length: 12500, dtype: int64

# %% [markdown]
# now i got two answers which making it unique then i ave come to conclusion that custumer_id Is what We usinG

# %%
dframe=df[['ID','Customer_ID','Month','Name','Age','SSN','Occupation','Annual_Income','Monthly_Inhand_Salary','Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Loan','Type_of_Loan','Delay_from_due_date','Num_of_Delayed_Payment','Changed_Credit_Limit','Num_Credit_Inquiries','Credit_Mix','Outstanding_Debt','Credit_Utilization_Ratio','Credit_History_Age','Payment_of_Min_Amount','Total_EMI_per_month','Amount_invested_monthly','Payment_Behaviour','Monthly_Balance','Credit_Score']].groupby('Customer_ID').first().reset_index()

# %%
dframe
# Out:
#        Customer_ID     ID  Month               Name   Age          SSN  \
# 0             1006  27750      1  Matthias Blamontb  37.0  354656948.0
# 1             1007  53250      1       Soyoung Kimu  48.0  964812710.0
# 2             1008  56850      1               Koht  37.0  802194704.0
# 3             1009  84330      1                Edd  22.0  891062189.0
# 4             1011  39354      1        Terry Wadeu  43.0  422130011.0
# ...            ...    ...    ...                ...   ...          ...
# 12495        50984  18798      1          Victoriah  20.0  151944427.0
# 12496        50990  99882      1               Yueo  38.0   94540952.0
# 12497        50992  50466      1       Jason Langev  23.0   76136508.0
# 12498        50996  80658      1           Koh Guia  38.0  946823382.0
# 12499        50999  86958      1     Simon Johnsong  46.0   87097867.0
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0         Journalist       16756.18            1331.348333                9.0
# 1            Manager       21212.91            1496.742500                3.0
# 2          Developer       33540.43            2655.035833                6.0
# 3         Accountant       80983.64            6692.636667                6.0
# 4             Writer      104142.56            8433.546667                3.0
# ...              ...            ...                    ...                ...
# 12495       Mechanic       19267.17            1531.597500                6.0
# 12496         Lawyer       32125.54            2559.128333                7.0
# 12497     Journalist        9608.03             735.669167                7.0
# 12498  Media_Manager       27305.93            2289.494167                3.0
# 12499         Doctor       78676.32            6710.360000                2.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  6.0           22.0          2.0
# 1                  4.0           10.0          3.0
# 2                  3.0           17.0          0.0
# 3                  3.0           15.0          4.0
# 4                  5.0            5.0          3.0
# ...                ...            ...          ...
# 12495              5.0           26.0          6.0
# 12496              9.0           23.0          3.0
# 12497              4.0           10.0          6.0
# 12498              4.0           19.0          0.0
# 12499              1.0            4.0          1.0
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 0                   Credit-Builder Loan, and Payday Loan                 48.0
# 1      Home Equity Loan, Mortgage Loan, and Student Loan                 19.0
# 2                                                No Data                 25.0
# 3      Credit-Builder Loan, Student Loan, Not Specifi...                 19.0
# 4                Personal Loan, Auto Loan, and Auto Loan                 15.0
# ...                                                  ...                  ...
# 12495  Home Equity Loan, Mortgage Loan, Payday Loan, ...                 13.0
# 12496            Mortgage Loan, Auto Loan, and Auto Loan                 15.0
# 12497  Student Loan, Credit-Builder Loan, Mortgage Lo...                  8.0
# 12498                                            No Data                 21.0
# 12499                                Credit-Builder Loan                  7.0
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                        10.0                 10.66                   8.0
# 1                        19.0                 12.13                   1.0
# 2                        11.0                 14.11                   6.0
# 3                        18.0                 16.91                   7.0
# 4                        17.0                 15.28                   6.0
# ...                       ...                   ...                   ...
# 12495                    12.0                 15.71                  12.0
# 12496                    16.0                  8.07                   8.0
# 12497                    14.0                 10.44                   5.0
# 12498                    17.0                  8.93                   6.0
# 12499                     1.0                 16.80                   4.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0       Standard           1941.73                 37.501111
# 1       Standard            993.15                 35.268983
# 2       Standard           1138.97                 27.816244
# 3       Standard            982.44                 39.755126
# 4       Standard           1371.80                 26.890190
# ...          ...               ...                       ...
# 12495   Standard           1732.19                 24.939468
# 12496   Standard           2557.14                 25.955617
# 12497   Standard           1494.17                 24.324514
# 12498   Standard            454.40                 38.424864
# 12499       Good           1080.98                 29.319202
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                   182.0                   Yes            27.442089
# 1                   346.0                    No            45.745700
# 2                   292.0                   Yes             0.000000
# 3                   331.0                   Yes           188.456595
# 4                   179.0                   Yes           257.738646
# ...                   ...                   ...                  ...
# 12495               157.0                   Yes            77.630937
# 12496                70.0                   Yes            59.330922
# 12497               159.0                   Yes            25.467999
# 12498               206.0                   Yes             0.000000
# 12499               226.0                    No            48.577978
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    45.301068  High_spent_Medium_value_payments
# 1                    30.373472  High_spent_Medium_value_payments
# 2                    50.930150   High_spent_Small_value_payments
# 3                   101.120201  High_spent_Medium_value_payments
# 4                   102.488034   High_spent_Small_value_payments
# ...                        ...                               ...
# 12495                47.873509    Low_spent_Small_value_payments
# 12496                34.883593   High_spent_Large_value_payments
# 12497                 0.000000   Low_spent_Medium_value_payments
# 12498                26.378439   Low_spent_Medium_value_payments
# 12499                48.317366   High_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score
# 0           310.391676         Poor
# 1           323.555078     Standard
# 2           406.622885     Standard
# 3           581.429820     Standard
# 4           553.403317     Standard
# ...                ...          ...
# 12495       210.594332         Poor
# 12496       385.513540         Poor
# 12497       307.711984     Standard
# 12498       368.442434     Standard
# 12499       700.663205         Good
#
# [12500 rows x 28 columns]

# %%
df['Customer_ID'].value_counts().unique()
# Out:
# array([8], dtype=int64)

# %% [markdown]
# So it appear that Every Each Custuemr on this dataset happen to hhave 8 Each duplicated with different Attribute but the same user ID.
#
# so there Is No Way the Appearence level will work when we gat Equall apearance.

# %%
dframe
# Out:
#        Customer_ID     ID  Month               Name   Age          SSN  \
# 0             1006  27750      1  Matthias Blamontb  37.0  354656948.0
# 1             1007  53250      1       Soyoung Kimu  48.0  964812710.0
# 2             1008  56850      1               Koht  37.0  802194704.0
# 3             1009  84330      1                Edd  22.0  891062189.0
# 4             1011  39354      1        Terry Wadeu  43.0  422130011.0
# ...            ...    ...    ...                ...   ...          ...
# 12495        50984  18798      1          Victoriah  20.0  151944427.0
# 12496        50990  99882      1               Yueo  38.0   94540952.0
# 12497        50992  50466      1       Jason Langev  23.0   76136508.0
# 12498        50996  80658      1           Koh Guia  38.0  946823382.0
# 12499        50999  86958      1     Simon Johnsong  46.0   87097867.0
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0         Journalist       16756.18            1331.348333                9.0
# 1            Manager       21212.91            1496.742500                3.0
# 2          Developer       33540.43            2655.035833                6.0
# 3         Accountant       80983.64            6692.636667                6.0
# 4             Writer      104142.56            8433.546667                3.0
# ...              ...            ...                    ...                ...
# 12495       Mechanic       19267.17            1531.597500                6.0
# 12496         Lawyer       32125.54            2559.128333                7.0
# 12497     Journalist        9608.03             735.669167                7.0
# 12498  Media_Manager       27305.93            2289.494167                3.0
# 12499         Doctor       78676.32            6710.360000                2.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  6.0           22.0          2.0
# 1                  4.0           10.0          3.0
# 2                  3.0           17.0          0.0
# 3                  3.0           15.0          4.0
# 4                  5.0            5.0          3.0
# ...                ...            ...          ...
# 12495              5.0           26.0          6.0
# 12496              9.0           23.0          3.0
# 12497              4.0           10.0          6.0
# 12498              4.0           19.0          0.0
# 12499              1.0            4.0          1.0
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 0                   Credit-Builder Loan, and Payday Loan                 48.0
# 1      Home Equity Loan, Mortgage Loan, and Student Loan                 19.0
# 2                                                No Data                 25.0
# 3      Credit-Builder Loan, Student Loan, Not Specifi...                 19.0
# 4                Personal Loan, Auto Loan, and Auto Loan                 15.0
# ...                                                  ...                  ...
# 12495  Home Equity Loan, Mortgage Loan, Payday Loan, ...                 13.0
# 12496            Mortgage Loan, Auto Loan, and Auto Loan                 15.0
# 12497  Student Loan, Credit-Builder Loan, Mortgage Lo...                  8.0
# 12498                                            No Data                 21.0
# 12499                                Credit-Builder Loan                  7.0
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                        10.0                 10.66                   8.0
# 1                        19.0                 12.13                   1.0
# 2                        11.0                 14.11                   6.0
# 3                        18.0                 16.91                   7.0
# 4                        17.0                 15.28                   6.0
# ...                       ...                   ...                   ...
# 12495                    12.0                 15.71                  12.0
# 12496                    16.0                  8.07                   8.0
# 12497                    14.0                 10.44                   5.0
# 12498                    17.0                  8.93                   6.0
# 12499                     1.0                 16.80                   4.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0       Standard           1941.73                 37.501111
# 1       Standard            993.15                 35.268983
# 2       Standard           1138.97                 27.816244
# 3       Standard            982.44                 39.755126
# 4       Standard           1371.80                 26.890190
# ...          ...               ...                       ...
# 12495   Standard           1732.19                 24.939468
# 12496   Standard           2557.14                 25.955617
# 12497   Standard           1494.17                 24.324514
# 12498   Standard            454.40                 38.424864
# 12499       Good           1080.98                 29.319202
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                   182.0                   Yes            27.442089
# 1                   346.0                    No            45.745700
# 2                   292.0                   Yes             0.000000
# 3                   331.0                   Yes           188.456595
# 4                   179.0                   Yes           257.738646
# ...                   ...                   ...                  ...
# 12495               157.0                   Yes            77.630937
# 12496                70.0                   Yes            59.330922
# 12497               159.0                   Yes            25.467999
# 12498               206.0                   Yes             0.000000
# 12499               226.0                    No            48.577978
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    45.301068  High_spent_Medium_value_payments
# 1                    30.373472  High_spent_Medium_value_payments
# 2                    50.930150   High_spent_Small_value_payments
# 3                   101.120201  High_spent_Medium_value_payments
# 4                   102.488034   High_spent_Small_value_payments
# ...                        ...                               ...
# 12495                47.873509    Low_spent_Small_value_payments
# 12496                34.883593   High_spent_Large_value_payments
# 12497                 0.000000   Low_spent_Medium_value_payments
# 12498                26.378439   Low_spent_Medium_value_payments
# 12499                48.317366   High_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score
# 0           310.391676         Poor
# 1           323.555078     Standard
# 2           406.622885     Standard
# 3           581.429820     Standard
# 4           553.403317     Standard
# ...                ...          ...
# 12495       210.594332         Poor
# 12496       385.513540         Poor
# 12497       307.711984     Standard
# 12498       368.442434     Standard
# 12499       700.663205         Good
#
# [12500 rows x 28 columns]

# %%
dframe['Credit_Score'].value_counts()
# Out:
# Standard    6943
# Poor        3582
# Good        1975
# Name: Credit_Score, dtype: int64

# %%
dframe['Credit_Mix'].value_counts()
# Out:
# Standard    5731
# Good        3798
# Bad         2971
# Name: Credit_Mix, dtype: int64

# %%
from sklearn.decomposition import PCA

# %%
num_df=dframe.select_dtypes('number')

# %%
pca=PCA()
pca.fit(num_df)
pd.DataFrame(index=num_df.columns,data=pca.explained_variance_ratio_,columns=['Feature_Importance'])
# Out:
#                           Feature_Importance
# Customer_ID                     1.000000e+00
# ID                              2.216777e-08
# Month                           1.746114e-08
# Age                             2.431020e-09
# SSN                             1.469528e-11
# Annual_Income                   3.807530e-13
# Monthly_Inhand_Salary           2.922212e-13
# Num_Bank_Accounts               8.184284e-14
# Num_Credit_Card                 5.797348e-14
# Interest_Rate                   6.224614e-15
# Num_of_Loan                     1.767167e-15
# Delay_from_due_date             1.274000e-15
# Num_of_Delayed_Payment          4.658430e-16
# Changed_Credit_Limit            3.767051e-16
# Num_Credit_Inquiries            2.892559e-16
# Outstanding_Debt                2.449309e-16
# Credit_Utilization_Ratio        5.692800e-17
# Credit_History_Age              3.916219e-17
# Total_EMI_per_month             3.177415e-17
# Amount_invested_monthly         2.136381e-17
# Monthly_Balance                 1.504235e-43

# %%
ndf=num_df[['Annual_Income','Monthly_Inhand_Salary','Num_Bank_Accounts','Num_Credit_Card','Num_of_Loan','Num_of_Delayed_Payment',
        'Outstanding_Debt','Credit_History_Age','Credit_Utilization_Ratio']]

# %%
ndf
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0           16756.18            1331.348333                9.0
# 1           21212.91            1496.742500                3.0
# 2           33540.43            2655.035833                6.0
# 3           80983.64            6692.636667                6.0
# 4          104142.56            8433.546667                3.0
# ...              ...                    ...                ...
# 12495       19267.17            1531.597500                6.0
# 12496       32125.54            2559.128333                7.0
# 12497        9608.03             735.669167                7.0
# 12498       27305.93            2289.494167                3.0
# 12499       78676.32            6710.360000                2.0
#
#        Num_Credit_Card  Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# 0                  6.0          2.0                    10.0           1941.73
# 1                  4.0          3.0                    19.0            993.15
# 2                  3.0          0.0                    11.0           1138.97
# 3                  3.0          4.0                    18.0            982.44
# 4                  5.0          3.0                    17.0           1371.80
# ...                ...          ...                     ...               ...
# 12495              5.0          6.0                    12.0           1732.19
# 12496              9.0          3.0                    16.0           2557.14
# 12497              4.0          6.0                    14.0           1494.17
# 12498              4.0          0.0                    17.0            454.40
# 12499              1.0          1.0                     1.0           1080.98
#
#        Credit_History_Age  Credit_Utilization_Ratio
# 0                   182.0                 37.501111
# 1                   346.0                 35.268983
# 2                   292.0                 27.816244
# 3                   331.0                 39.755126
# 4                   179.0                 26.890190
# ...                   ...                       ...
# 12495               157.0                 24.939468
# 12496                70.0                 25.955617
# 12497               159.0                 24.324514
# 12498               206.0                 38.424864
# 12499               226.0                 29.319202
#
# [12500 rows x 9 columns]

# %%
import sketch

ndf.sketch.ask('can you give me a friendly names and single sentence descriptions of each column ?(format output as HTML List)')
# Out:
# <ul>
#   <li>Index: A numerical identifier for each row in the dataframe.</li>
#   <li>Annual_Income: The annual income of each customer in the dataframe.</li>
#   <li>Monthly_Inhand_Salary: The monthly salary of each customer in the dataframe.</li>
#   <li>Num_Bank_Accounts: The number of bank accounts held by each customer in the dataframe.</li>
#   <li>Num_Credit_Card: The number of credit cards held by each customer in the dataframe.</li>
#   <li>Num_of_Loan: The number of loans taken by each customer in the dataframe.</li>
#   <li>Num_of_Delayed_Payment: The number of delayed payments made by each customer in the dataframe.</li>
#   <li>Outstanding_Debt: The outstanding debt of each customer in the dataframe.</li>
#   <li>Credit_History_Age: The age of credit history of each customer in the dataframe.</li>
#   <li>Credit_Utilization_Ratio: The credit utilization ratio of each customer in the dataframe.</li>
# </ul>

# %%
# I think We are good to go?
#let have A View 

ndf.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       16756.18            1331.348333                9.0              6.0
# 1       21212.91            1496.742500                3.0              4.0
# 2       33540.43            2655.035833                6.0              3.0
# 3       80983.64            6692.636667                6.0              3.0
# 4      104142.56            8433.546667                3.0              5.0
#
#    Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  Credit_History_Age  \
# 0          2.0                    10.0           1941.73               182.0
# 1          3.0                    19.0            993.15               346.0
# 2          0.0                    11.0           1138.97               292.0
# 3          4.0                    18.0            982.44               331.0
# 4          3.0                    17.0           1371.80               179.0
#
#    Credit_Utilization_Ratio
# 0                 37.501111
# 1                 35.268983
# 2                 27.816244
# 3                 39.755126
# 4                 26.890190

# %%
ndf.describe()
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count   12500.000000           12500.000000       12500.000000
# mean    50505.123449            4206.144676           5.367520
# std     38300.762656            3193.075036           2.592394
# min      7005.930000             303.645417           0.000000
# 25%     19342.972500            1628.777917           3.000000
# 50%     36999.705000            3100.995417           5.000000
# 75%     71683.470000            5971.194583           7.000000
# max    179987.280000           15204.633333          10.000000
#
#        Num_Credit_Card   Num_of_Loan  Num_of_Delayed_Payment  \
# count     12500.000000  12500.000000            12500.000000
# mean          5.532400      3.532880               13.306080
# std           2.063669      2.446442                6.253063
# min           1.000000      0.000000                0.000000
# 25%           4.000000      2.000000                9.000000
# 50%           5.000000      3.000000               14.000000
# 75%           7.000000      5.000000               18.000000
# max          10.000000      9.000000               25.000000
#
#        Outstanding_Debt  Credit_History_Age  Credit_Utilization_Ratio  \
# count      12500.000000        12500.000000              12500.000000
# mean        1426.220376          217.805280                 32.291949
# std         1155.169458           99.659358                  5.084327
# min            0.230000            1.000000                 20.992914
# 25%          566.072500          141.000000                 28.110034
# 50%         1166.155000          216.000000                 32.297912
# 75%         1945.962500          298.000000                 36.458660
# max         4998.070000          397.000000                 49.564519
#
#             Cluster
# count  12500.000000
# mean       1.924000
# std        1.423793
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000

# %%
ndf.head(3)
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       16756.18            1331.348333                9.0              6.0
# 1       21212.91            1496.742500                3.0              4.0
# 2       33540.43            2655.035833                6.0              3.0
#
#    Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  Credit_History_Age  \
# 0          2.0                    10.0           1941.73               182.0
# 1          3.0                    19.0            993.15               346.0
# 2          0.0                    11.0           1138.97               292.0
#
#    Credit_Utilization_Ratio  Cluster
# 0                 37.501111        3
# 1                 35.268983        0
# 2                 27.816244        0

# %%
Label=ndf[['Num_of_Loan','Outstanding_Debt','Num_of_Delayed_Payment']]

def unique(Label):
    for i in Label.columns:
        print(f'{i}:{ndf[i].unique()}')

# %%
unique(Label)
# Out:
# Num_of_Loan:[2. 3. 0. 4. 7. 1. 6. 5. 8. 9.]
# Outstanding_Debt:[1941.73  993.15 1138.97 ... 2557.14 1494.17 1080.98]
# Num_of_Delayed_Payment:[10. 19. 11. 18. 17.  2. 14. 23.  8. 25.  4. 12. 13.  5. 16. 20. 15.  1.
#  22.  7.  3.  6.  9.  0. 24. 21.]

# %%
ndf['Outstanding_Debt'].unique()
# Out:
# array([1941.73,  993.15, 1138.97, ..., 2557.14, 1494.17, 1080.98])

# %%
#having done all of That
#first Let Share each columns equal weight so one won't have more influence over others

from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler.fit(ndf)
# Out:
# StandardScaler()

# %%
scalerX=scaler.transform(ndf)

# %%
#yes, let import Kmeans

from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=8,init='k-means++',max_iter=1000)

# %%
kmeans.fit(scalerX)
# Out:
# KMeans(max_iter=1000)

# %%
kmeans.inertia_
# Out:
# 45669.818750859566

# %% [markdown]
# #better result!

# %%
# fitting multiple k-means algorithms and storing the values in an empty list
SSE = []
for cluster in range(1,20):
    kmeans = KMeans(n_clusters = cluster, init='k-means++')
    kmeans.fit(scalerX)
    SSE.append(kmeans.inertia_)

# %%
# converting the results into a dataframe and plotting them


frame = pd.DataFrame({'Cluster':range(1,20), 'SSE':SSE})
plt.figure(figsize=(12,10),dpi=100)
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.xticks(np.arange(1,20))
plt.grid()

# %% [markdown]
# #am going to be trying 4,5 and 6

# %%
# k means using 5 clusters and k-means++ initialization
kmeans = KMeans(n_clusters = 5, init='k-means++')
kmeans.fit(scalerX)
pred = kmeans.predict(scalerX)

# %%
#group The clustering

clustering= pd.DataFrame(scalerX)
clustering['cluster'] = pred
clustering['cluster'].value_counts()
# Out:
# 0    2868
# 3    2837
# 1    2401
# 2    2219
# 4    2175
# Name: cluster, dtype: int64

# %%
ndf['Cluster']=pred
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18964\2975285694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['Cluster']=pred

# %%
ndf
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0           16756.18            1331.348333                9.0
# 1           21212.91            1496.742500                3.0
# 2           33540.43            2655.035833                6.0
# 3           80983.64            6692.636667                6.0
# 4          104142.56            8433.546667                3.0
# ...              ...                    ...                ...
# 12495       19267.17            1531.597500                6.0
# 12496       32125.54            2559.128333                7.0
# 12497        9608.03             735.669167                7.0
# 12498       27305.93            2289.494167                3.0
# 12499       78676.32            6710.360000                2.0
#
#        Num_Credit_Card  Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# 0                  6.0          2.0                    10.0           1941.73
# 1                  4.0          3.0                    19.0            993.15
# 2                  3.0          0.0                    11.0           1138.97
# 3                  3.0          4.0                    18.0            982.44
# 4                  5.0          3.0                    17.0           1371.80
# ...                ...          ...                     ...               ...
# 12495              5.0          6.0                    12.0           1732.19
# 12496              9.0          3.0                    16.0           2557.14
# 12497              4.0          6.0                    14.0           1494.17
# 12498              4.0          0.0                    17.0            454.40
# 12499              1.0          1.0                     1.0           1080.98
#
#        Credit_History_Age  Credit_Utilization_Ratio  Cluster
# 0                   182.0                 37.501111        3
# 1                   346.0                 35.268983        0
# 2                   292.0                 27.816244        0
# 3                   331.0                 39.755126        1
# 4                   179.0                 26.890190        1
# ...                   ...                       ...      ...
# 12495               157.0                 24.939468        3
# 12496                70.0                 25.955617        3
# 12497               159.0                 24.324514        3
# 12498               206.0                 38.424864        0
# 12499               226.0                 29.319202        4
#
# [12500 rows x 10 columns]

# %%
ndf.describe().T
# Out:
#                             count          mean           std          min  \
# Annual_Income             12500.0  50505.123449  38300.762656  7005.930000
# Monthly_Inhand_Salary     12500.0   4206.144676   3193.075036   303.645417
# Num_Bank_Accounts         12500.0      5.367520      2.592394     0.000000
# Num_Credit_Card           12500.0      5.532400      2.063669     1.000000
# Num_of_Loan               12500.0      3.532880      2.446442     0.000000
# Num_of_Delayed_Payment    12500.0     13.306080      6.253063     0.000000
# Outstanding_Debt          12500.0   1426.220376   1155.169458     0.230000
# Credit_History_Age        12500.0    217.805280     99.659358     1.000000
# Credit_Utilization_Ratio  12500.0     32.291949      5.084327    20.992914
# Cluster                   12500.0      1.924000      1.423793     0.000000
#
#                                    25%           50%           75%  \
# Annual_Income             19342.972500  36999.705000  71683.470000
# Monthly_Inhand_Salary      1628.777917   3100.995417   5971.194583
# Num_Bank_Accounts             3.000000      5.000000      7.000000
# Num_Credit_Card               4.000000      5.000000      7.000000
# Num_of_Loan                   2.000000      3.000000      5.000000
# Num_of_Delayed_Payment        9.000000     14.000000     18.000000
# Outstanding_Debt            566.072500   1166.155000   1945.962500
# Credit_History_Age          141.000000    216.000000    298.000000
# Credit_Utilization_Ratio     28.110034     32.297912     36.458660
# Cluster                       1.000000      2.000000      3.000000
#
#                                     max
# Annual_Income             179987.280000
# Monthly_Inhand_Salary      15204.633333
# Num_Bank_Accounts             10.000000
# Num_Credit_Card               10.000000
# Num_of_Loan                    9.000000
# Num_of_Delayed_Payment        25.000000
# Outstanding_Debt            4998.070000
# Credit_History_Age           397.000000
# Credit_Utilization_Ratio      49.564519
# Cluster                        4.000000

# %%
ndf.query('Cluster==1').describe()
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count    2401.000000            2401.000000        2401.000000
# mean   114907.528326            9573.203536           3.849229
# std     25599.439380            2133.540031           2.168661
# min     66092.250000            5503.261667           0.000000
# 25%     94159.710000            7860.352500           2.000000
# 50%    110468.490000            9238.836667           4.000000
# 75%    131254.800000           10918.730000           5.000000
# max    179987.280000           15204.633333           8.000000
#
#        Num_Credit_Card  Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# count      2401.000000  2401.000000             2401.000000       2401.000000
# mean          4.607663     2.185339                9.545606        745.927230
# std           1.618438     1.580944                5.366379        437.653269
# min           1.000000     0.000000                0.000000          0.540000
# 25%           3.000000     1.000000                5.000000        381.060000
# 50%           5.000000     2.000000                9.000000        722.900000
# 75%           6.000000     3.000000               13.000000       1128.730000
# max           7.000000     7.000000               23.000000       2696.610000
#
#        Credit_History_Age  Credit_Utilization_Ratio  Cluster
# count         2401.000000               2401.000000   2401.0
# mean           274.767597                 34.404935      1.0
# std             73.883795                  5.192543      0.0
# min             61.000000                 21.542892      1.0
# 25%            218.000000                 30.218740      1.0
# 50%            274.000000                 34.459886      1.0
# 75%            339.000000                 38.437060      1.0
# max            397.000000                 49.564519      1.0

# %%
ndf.query('Cluster==2').describe()
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count    2219.000000            2219.000000        2219.000000
# mean    32654.544824            2720.641888           8.065345
# std     22139.871706            1847.340862           1.422720
# min      7006.035000             303.645417           3.000000
# 25%     15344.645000            1229.734167           7.000000
# 50%     20483.840000            1817.321667           8.000000
# 75%     51402.510000            4294.638750           9.000000
# max     83990.680000            7268.263333          10.000000
#
#        Num_Credit_Card  Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# count      2219.000000  2219.000000             2219.000000       2219.000000
# mean          7.724200     6.993240               20.027941       3386.890852
# std           1.687648     1.451174                3.294958        933.734801
# min           5.000000     2.000000                6.000000       1253.640000
# 25%           6.000000     6.000000               17.000000       2633.730000
# 50%           8.000000     7.000000               20.000000       3398.950000
# 75%           9.000000     8.000000               23.000000       4177.175000
# max          10.000000     9.000000               25.000000       4998.070000
#
#        Credit_History_Age  Credit_Utilization_Ratio  Cluster
# count         2219.000000               2219.000000   2219.0
# mean            98.406940                 31.431786      2.0
# std             54.923742                  4.974910      0.0
# min              1.000000                 21.317598      2.0
# 25%             57.000000                 27.138838      2.0
# 50%             97.000000                 31.441164      2.0
# 75%            141.000000                 35.628734      2.0
# max            241.000000                 41.575810      2.0

# %%
df.describe(include='all').T
# Out:
#                              count unique                             top  \
# ID                        100000.0    NaN                             NaN
# Customer_ID               100000.0    NaN                             NaN
# Month                     100000.0    NaN                             NaN
# Name                        100000  10128                        Jessicad
# Age                       100000.0    NaN                             NaN
# SSN                       100000.0    NaN                             NaN
# Occupation                  100000     15                          Lawyer
# Annual_Income             100000.0    NaN                             NaN
# Monthly_Inhand_Salary     100000.0    NaN                             NaN
# Num_Bank_Accounts         100000.0    NaN                             NaN
# Num_Credit_Card           100000.0    NaN                             NaN
# Interest_Rate             100000.0    NaN                             NaN
# Num_of_Loan               100000.0    NaN                             NaN
# Type_of_Loan                100000   6261                         No Data
# Delay_from_due_date       100000.0    NaN                             NaN
# Num_of_Delayed_Payment    100000.0    NaN                             NaN
# Changed_Credit_Limit      100000.0    NaN                             NaN
# Num_Credit_Inquiries      100000.0    NaN                             NaN
# Credit_Mix                  100000      3                        Standard
# Outstanding_Debt          100000.0    NaN                             NaN
# Credit_Utilization_Ratio  100000.0    NaN                             NaN
# Credit_History_Age        100000.0    NaN                             NaN
# Payment_of_Min_Amount       100000      3                             Yes
# Total_EMI_per_month       100000.0    NaN                             NaN
# Amount_invested_monthly   100000.0    NaN                             NaN
# Payment_Behaviour           100000      6  Low_spent_Small_value_payments
# Monthly_Balance           100000.0    NaN                             NaN
# Credit_Score                100000      3                        Standard
#
#                            freq            mean               std         min  \
# ID                          NaN         80631.5      43301.486619      5634.0
# Customer_ID                 NaN     25982.66664      14340.543051      1006.0
# Month                       NaN             4.5          2.291299         1.0
# Name                         48             NaN               NaN         NaN
# Age                         NaN        33.31634         10.764812        14.0
# SSN                         NaN  500461680.2624  290826734.386185     81349.0
# Occupation                 7096             NaN               NaN         NaN
# Annual_Income               NaN    50505.123449      38299.422093     7005.93
# Monthly_Inhand_Salary       NaN     4197.270835       3186.432497  303.645417
# Num_Bank_Accounts           NaN         5.36882          2.593314         0.0
# Num_Credit_Card             NaN         5.53357          2.067098         0.0
# Interest_Rate               NaN        14.53208           8.74133         1.0
# Num_of_Loan                 NaN         3.53288          2.446356         0.0
# Type_of_Loan              11408             NaN               NaN         NaN
# Delay_from_due_date         NaN        21.08141          14.80456         0.0
# Num_of_Delayed_Payment      NaN        13.31312          6.237166         0.0
# Changed_Credit_Limit        NaN       10.470323          6.609481         0.5
# Num_Credit_Inquiries        NaN         5.79825          3.867826         0.0
# Credit_Mix                45848             NaN               NaN         NaN
# Outstanding_Debt            NaN     1426.220376       1155.129026        0.23
# Credit_Utilization_Ratio    NaN       32.285173          5.116875        20.0
# Credit_History_Age          NaN       221.22046         99.680716         1.0
# Payment_of_Min_Amount     52326             NaN               NaN         NaN
# Total_EMI_per_month         NaN      107.699208        132.267056         0.0
# Amount_invested_monthly     NaN       55.101315         39.006932         0.0
# Payment_Behaviour         28616             NaN               NaN         NaN
# Monthly_Balance             NaN      392.697586        201.652719     0.00776
# Credit_Score              53174             NaN               NaN         NaN
#
#                                    25%          50%           75%  \
# ID                            43132.75      80631.5     118130.25
# Customer_ID                    13664.5      25777.0       38385.0
# Month                             2.75          4.5          6.25
# Name                               NaN          NaN           NaN
# Age                               24.0         33.0          42.0
# SSN                       245168577.25  500688611.5  756002666.25
# Occupation                         NaN          NaN           NaN
# Annual_Income               19342.9725    36999.705      71683.47
# Monthly_Inhand_Salary      1626.594167     3095.905      5957.715
# Num_Bank_Accounts                  3.0          5.0           7.0
# Num_Credit_Card                    4.0          5.0           7.0
# Interest_Rate                      7.0         13.0          20.0
# Num_of_Loan                        2.0          3.0           5.0
# Type_of_Loan                       NaN          NaN           NaN
# Delay_from_due_date               10.0         18.0          28.0
# Num_of_Delayed_Payment             9.0         14.0          18.0
# Changed_Credit_Limit              5.38          9.4         14.85
# Num_Credit_Inquiries               3.0          5.0           8.0
# Credit_Mix                         NaN          NaN           NaN
# Outstanding_Debt              566.0725     1166.155     1945.9625
# Credit_Utilization_Ratio     28.052567    32.305784     36.496663
# Credit_History_Age               144.0        219.0         302.0
# Payment_of_Min_Amount              NaN          NaN           NaN
# Total_EMI_per_month          29.268886    66.462304    147.392573
# Amount_invested_monthly      27.959111     45.15655     71.295797
# Payment_Behaviour                  NaN          NaN           NaN
# Monthly_Balance             267.615983   333.865366    463.215683
# Credit_Score                       NaN          NaN           NaN
#
#                                    max
# ID                            155629.0
# Customer_ID                    50999.0
# Month                              8.0
# Name                               NaN
# Age                               56.0
# SSN                        999993421.0
# Occupation                         NaN
# Annual_Income                179987.28
# Monthly_Inhand_Salary     15204.633333
# Num_Bank_Accounts                 11.0
# Num_Credit_Card                   11.0
# Interest_Rate                     34.0
# Num_of_Loan                        9.0
# Type_of_Loan                       NaN
# Delay_from_due_date               62.0
# Num_of_Delayed_Payment            25.0
# Changed_Credit_Limit             29.98
# Num_Credit_Inquiries              17.0
# Credit_Mix                         NaN
# Outstanding_Debt               4998.07
# Credit_Utilization_Ratio          50.0
# Credit_History_Age               404.0
# Payment_of_Min_Amount              NaN
# Total_EMI_per_month        1779.103254
# Amount_invested_monthly     434.191089
# Payment_Behaviour                  NaN
# Monthly_Balance            1183.930696
# Credit_Score                       NaN

# %%
#Defining The criteriat


def criteriat(X):
    if X[0] >= 7 and X[1] <=5:
        return "Top_Custumer"
    elif X[0] >= 6 and X[1] >= 6 or X[1] >=10:
        return "Good Custumer"
    elif X[0] >=5 and X[1] <=11 or X[1] >=15:
        return 'Not Bad'
    elif X[0] >=4 and X[1] <=16 or X[1]>=20:
        return "bad"
    elif X[0] >=3 and X[1] <=21 or X[1]>=25:
        return "Risky"
    elif X[0] <=2 and X[1] >=25:
        return "Too_Risky"

# %%
ndf['Class']=ndf[['Num_of_Loan','Num_of_Delayed_Payment']].apply(lambda X: (criteriat(X)),axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18964\2672306190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['Class']=ndf[['Num_of_Loan','Num_of_Delayed_Payment']].apply(lambda X: (criteriat(X)),axis=1)

# %%
ndf
# Out:
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0           16756.18            1331.348333                9.0
# 1           21212.91            1496.742500                3.0
# 2           33540.43            2655.035833                6.0
# 3           80983.64            6692.636667                6.0
# 4          104142.56            8433.546667                3.0
# ...              ...                    ...                ...
# 12495       19267.17            1531.597500                6.0
# 12496       32125.54            2559.128333                7.0
# 12497        9608.03             735.669167                7.0
# 12498       27305.93            2289.494167                3.0
# 12499       78676.32            6710.360000                2.0
#
#        Num_Credit_Card  Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# 0                  6.0          2.0                    10.0           1941.73
# 1                  4.0          3.0                    19.0            993.15
# 2                  3.0          0.0                    11.0           1138.97
# 3                  3.0          4.0                    18.0            982.44
# 4                  5.0          3.0                    17.0           1371.80
# ...                ...          ...                     ...               ...
# 12495              5.0          6.0                    12.0           1732.19
# 12496              9.0          3.0                    16.0           2557.14
# 12497              4.0          6.0                    14.0           1494.17
# 12498              4.0          0.0                    17.0            454.40
# 12499              1.0          1.0                     1.0           1080.98
#
#        Credit_History_Age  Credit_Utilization_Ratio  Cluster          Class
# 0                   182.0                 37.501111        3  Good Custumer
# 1                   346.0                 35.268983        0  Good Custumer
# 2                   292.0                 27.816244        0  Good Custumer
# 3                   331.0                 39.755126        1  Good Custumer
# 4                   179.0                 26.890190        1  Good Custumer
# ...                   ...                       ...      ...            ...
# 12495               157.0                 24.939468        3  Good Custumer
# 12496                70.0                 25.955617        3  Good Custumer
# 12497               159.0                 24.324514        3  Good Custumer
# 12498               206.0                 38.424864        0  Good Custumer
# 12499               226.0                 29.319202        4           None
#
# [12500 rows x 11 columns]

# %% [markdown]
# #problems solve so by doing all of this i have easily label out our custumers by their behaaviour pattern.
#
# so the company can Now lend Out their loan without been worried, atleast 75% assures that those custumers labels Top Custumer can be given loan without hhaving a doubt mind.

# %%
ndf['Class'].value_counts()
# Out:
# Good Custumer    9102
# Risky             727
# bad               642
# Not Bad            62
# Top_Custumer        1
# Name: Class, dtype: int64

# %%
ndf.query('Class=="Top_Custumer"')
# Out:
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 1267       83237.52                7162.46                8.0
#
#       Num_Credit_Card  Num_of_Loan  Num_of_Delayed_Payment  Outstanding_Debt  \
# 1267              7.0          7.0                     5.0           2652.42
#
#       Credit_History_Age  Credit_Utilization_Ratio  Cluster         Class
# 1267               219.0                 25.619947        3  Top_Custumer

# %% [markdown]
# We Segemented these Custumers based on The Repayment behaviourism.
